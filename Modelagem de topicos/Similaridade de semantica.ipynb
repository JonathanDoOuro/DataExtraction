# %% [markdown]
# ##Algoritmo para metrificar semelhança de semantica

# %%
# %pip install -U sentence-transformers

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

# %%
def similaridade(topicoModelado, topicoCorreto):
  embeddingsModelado = model.encode(topicoModelado)

  embeddingsManual = model.encode(topicoCorreto)

  cos_sim = util.cos_sim(embeddingsModelado, embeddingsManual)

  return float(cos_sim[0][0].item())

def similaridades(outputModelo, labels):
  similaridades = []

  for topicoModelado, topicoCorreto in zip(outputModelo, labels):
    similaridades.append(similaridade(topicoModelado, topicoCorreto))
  return similaridades

# %%
outputBertopic = ["geneticamente modificar tabaco comercializar aprovar", "fóssil classificação filogenio evolução taxonomia"]

labelsmanuais = ["genetica lograr exito", "evolução fossil anatomia organismo espécies"]

# %%
import pandas as pd

similaridadesObtidas = similaridades(outputBertopic, labelsmanuais)

nome = "aaaaaaaaaaaaaaaa"

df = pd.DataFrame({
    'topicos obtixxxdos': outputBertopic,
    'topicos esperados': labelsmanuais,
    'similaridade': similaridadesObtidas
})

df.to_csv(f'resultadosAnalise{nome}.csv', index=False)

# %%
print(similaridadesObtidas)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil

shutil.move("/content/resultadosAnalise.csv", "/content/drive/MyDrive/ModelosNLP/meu_arquivo.csv")
# Out:
# '/content/drive/MyDrive/ModelosNLP/meu_arquivo.csv'
